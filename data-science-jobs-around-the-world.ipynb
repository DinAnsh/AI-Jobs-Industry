# %%
import numpy as np
import pandas as pd
import re
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/data-science-jobs-around-the-world/AIJobsIndustry.csv

# %%
df = pd.read_csv('/kaggle/input/data-science-jobs-around-the-world/AIJobsIndustry.csv')

# %%
df.shape
# Out:
# (65670, 5)

# %%
df.describe()
# Out:
#               JobTitle       Company Location CompanyReviews  \
# count            56603         23459    65670          27705
# unique           20578          2951     2702           1985
# top     Data Scientist  \n    Google   London      2 reviews
# freq              1867           674     1704           1038
#
#                                                      Link
# count                                               65670
# unique                                              58667
# top     http://hu.indeed.com/jobs?q=Python+Data&start=...
# freq                                                   14

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65670 entries, 0 to 65669
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   JobTitle        56603 non-null  object
#  1   Company         23459 non-null  object
#  2   Location        65670 non-null  object
#  3   CompanyReviews  27705 non-null  object
#  4   Link            65670 non-null  object
# dtypes: object(5)
# memory usage: 2.5+ MB

# %%
df.head(10)
# Out:
#                                             JobTitle  \
# 0                                                NaN
# 1  Data Science Development Program- Junior Data ...
# 2                                 Sr. Data Scientist
# 3                         Object-oriented Programmer
# 4  Entry-Level Cognitive / AI / Machine Learning ...
# 5                               PHP/MySQL Programmer
# 6                              Healthcare Programmer
# 7                                         Programmer
# 8                              Python Programmer Job
# 9                                         BI Analyst
#
#                              Company             Location  CompanyReviews  \
# 0                                NaN        United States             NaN
# 1                   \n    MassMutual    Amherst, MA 01002     628 reviews
# 2                      \n    Catasys           Home Based       6 reviews
# 3              \n    Bank of America  New York, NY 10281   19,303 reviews
# ...

# %%
df.isnull().sum()
# Out:
# JobTitle           9067
# Company           42211
# Location              0
# CompanyReviews    37965
# Link                  0
# dtype: int64
